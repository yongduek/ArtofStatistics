# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
df = pd.read_csv('02-7-pop-past-future million in 51.csv')

# %%
df.tail()
# Out:
#     Year       China       India  United States of America  \
# 61  2011  1367480.26  1247236.03                 311051.37
# 62  2012  1375198.62  1263065.85                 313335.42
# 63  2013  1382793.21  1278562.21                 315536.68
# 64  2014  1390110.39  1293859.29                 317718.78
# 65  2015  1397028.55  1309053.98                 319929.16
#
#     Russian Federation      Japan  Indonesia   Germany     Brazil  \
# 61           143263.99  128505.40  245707.51  80933.98  198686.69
# 62           143420.60  128426.38  248883.23  81066.23  200560.98
# 63           143597.23  128312.92  252032.26  81265.14  202408.63
# 64           143761.38  128162.87  255131.12  81489.66  204213.13
# 65           143888.00  127974.96  258162.11  81707.79  205962.11
#
#     United Kingdom  ...   Israel  Central African Republic  Nicaragua  \
# 61        63811.88  ...  7568.77                   4476.15    5807.82
# ...

# %%
df.plot(x='Year', legend=False, figsize=(16,9));

# %%
plt.figure(figsize=(16,9))
plt.plot(df.Year, df.China)

# %%
keys = list( df.keys() )
keys[:5]
# Out:
# ['Year', 'China', 'India', 'United States of America', 'Russian Federation']

# %%
keys.remove('Year')
keys[:5]
# Out:
# ['China', 'India', 'United States of America', 'Russian Federation', 'Japan']

# %%
plt.figure(figsize=(16,9))
for i, k in enumerate(keys):
    plt.plot(df.Year, df[k])
    plt.text(x=df.Year[10], y=df[k][10], s=k)

# %%
'Europe' in keys
# Out:
# False

# %%
pt = pd.read_csv('02-7-pop-past-future-2.7-necessities.csv')
pt.tail()
# Out:
#     Year  Europe  World  Africa  Asia  Oceania  NorthernAmerica  \
# 61  2011     738   7043    1077  4240       37              346
# 62  2012     739   7128    1105  4286       38              348
# 63  2013     740   7213    1134  4331       38              351
# 64  2014     740   7298    1164  4376       39              353
# 65  2015     741   7383    1194  4420       40              356
#
#     LatinAmericaandCarribean  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 61                       605         NaN         NaN          NaN
# 62                       612         NaN         NaN          NaN
# 63                       619         NaN         NaN          NaN
# 64                       626         NaN         NaN          NaN
# 65                       632         NaN         NaN          NaN
#
#     Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 61          NaN          NaN          NaN          NaN
# 62          NaN          NaN          NaN          NaN
# ...

# %%
ptkeys = list(pt.keys())
ptkeys
# Out:
# ['Year',
#  'Europe',
#  'World',
#  'Africa',
#  'Asia',
#  'Oceania',
#  'NorthernAmerica',
#  'LatinAmericaandCarribean',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14']

# %%
ptkeys=ptkeys[1:8]
ptkeys
# Out:
# ['Europe',
#  'World',
#  'Africa',
#  'Asia',
#  'Oceania',
#  'NorthernAmerica',
#  'LatinAmericaandCarribean']

# %%
plt.figure(figsize=(16,9))
for i, k in enumerate(ptkeys):
    plt.plot(pt.Year, pt[k], lw=3, label=k)
    loc = i*10
    plt.text(x=pt.Year[loc], y=pt[k][loc], s=k, )
plt.legend();
plt.savefig('figure-2.7a.png')

# %%
plt.figure(figsize=(16,9))
for i, k in enumerate(ptkeys):
    plt.plot(pt.Year, pt[k], lw=3, label=k)
    loc = i*10
    plt.text(x=pt.Year[loc], y=pt[k][loc], s=k, )
plt.legend();
plt.yscale('log')
plt.ylabel('Population (Million)')
plt.savefig('figure-2.7b-log10.png')

# %%
plt.figure(figsize=(16,9))
for i, k in enumerate(ptkeys):
    plt.plot(pt.Year, pt[k], lw=5, label=k)
    loc = i*10
    plt.text(x=pt.Year[loc], y=pt[k][loc], s=k, )

for i, k in enumerate(keys):
    plt.plot(df.Year, df[k] / 1000, alpha=.3)
plt.plot(df.Year, df.China / 1000)

plt.yscale('log')
plt.ylabel('Population (Million)');
plt.savefig('figure-2.7b-log10-allcountries.png')

# %%
df.keys()
# Out:
# Index(['Year', 'China', 'India', 'United States of America',
#        'Russian Federation', 'Japan', 'Indonesia', 'Germany', 'Brazil',
#        'United Kingdom',
#        ...
#        'Israel', 'Central African Republic', 'Nicaragua', 'TFYR Macedonia',
#        'Albania', 'Turkmenistan', 'Eritrea', 'Libya', 'Estonia', 'Singapore'],
#       dtype='object', length=141)

# %%
year = df.Year.values

# %%
ratios = {}
for k in keys:
    ratios[k] = df[k].iloc[-1] / df[k].iloc[0]

# %%
keys = np.array(keys)

# %%
keys
# Out:
# array(['China', 'India', 'United States of America', 'Russian Federation',
#        'Japan', 'Indonesia', 'Germany', 'Brazil', 'United Kingdom',
#        'Northern Africa', 'Italy', 'France', 'Bangladesh', 'Nigeria',
#        'Pakistan', 'Ukraine', 'Mexico', 'Spain', 'Viet Nam', 'Poland',
#        'Turkey', 'Thailand', 'Egypt', 'Republic of Korea', 'Philippines',
#        'Ethiopia', 'Iran (Islamic Republic of)', 'Argentina', 'Myanmar',
#        'Caribbean', 'Romania', 'Southern Africa', 'Canada',
#        'South Africa', 'Oceania', 'Colombia',
#        'Democratic Republic of the Congo', 'Australia/New Zealand',
#        "Dem. People's Republic of Korea", 'Netherlands', 'Hungary',
#        'Morocco', 'Algeria', 'Czechia', 'Belgium', 'Nepal', 'Portugal',
#        'Australia', 'Sri Lanka', 'Peru',
#        'China, Taiwan Province of China', 'United Republic of Tanzania',
#        'Afghanistan', 'Greece', 'Belarus', 'Bulgaria', 'Sweden',
# ...

# %%
ratios['Republic of Korea']
# Out:
# 2.6335241749816127

# %%
df['Republic of Korea']
# Out:
# 0     19211.39
# 1     19459.43
# 2     19829.39
# 3     20307.90
# 4     20880.43
#         ...
# 61    49744.66
# 62    49952.24
# 63    50169.24
# 64    50385.56
# 65    50593.66
# Name: Republic of Korea, Length: 66, dtype: float64

# %%
df
# Out:
#     Year       China       India  United States of America  \
# 0   1950   554419.28   376325.20                 158804.40
# 1   1951   569611.08   382245.30                 160905.04
# 2   1952   582029.30   388538.62                 163324.85
# 3   1953   592567.86   395160.09                 165988.19
# 4   1954   601971.22   402077.03                 168827.61
# ..   ...         ...         ...                       ...
# 61  2011  1367480.26  1247236.03                 311051.37
# 62  2012  1375198.62  1263065.85                 313335.42
# 63  2013  1382793.21  1278562.21                 315536.68
# 64  2014  1390110.39  1293859.29                 317718.78
# 65  2015  1397028.55  1309053.98                 319929.16
#
#     Russian Federation      Japan  Indonesia   Germany     Brazil  \
# 0            102798.66   82802.08   69543.32  69966.24   53974.73
# 1            104306.14   84315.60   70869.61  70299.36   55619.22
# ...

# %%
df2 = df.set_index('Year')

# %%
df2['Republic of Korea']
# Out:
# Year
# 1950    19211.39
# 1951    19459.43
# 1952    19829.39
# 1953    20307.90
# 1954    20880.43
#           ...
# 2011    49744.66
# 2012    49952.24
# 2013    50169.24
# 2014    50385.56
# 2015    50593.66
# Name: Republic of Korea, Length: 66, dtype: float64
